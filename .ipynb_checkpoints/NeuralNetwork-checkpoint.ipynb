# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import pickle

# %%
data=pd.read_csv("trimmed_data.csv",index_col=0)
#data=pd.read_csv("new_data.csv",index_col=0)

# %%
corr = data.corr()
corr.style.background_gradient(cmap='binary')
# Out:
# <style  type="text/css" >
#     #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row0_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row0_col1 {
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row0_col2 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row0_col3 {
#             background-color:  #e7e7e7;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row0_col4 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row0_col5 {
#             background-color:  #eeeeee;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row0_col6 {
#             background-color:  #f5f5f5;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row0_col7 {
#             background-color:  #eaeaea;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row0_col8 {
#             background-color:  #eeeeee;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row1_col0 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row1_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row1_col2 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row1_col3 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row1_col4 {
#             background-color:  #f7f7f7;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row1_col5 {
#             background-color:  #efefef;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row1_col6 {
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row1_col7 {
#             background-color:  #f7f7f7;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row1_col8 {
#             background-color:  #ededed;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row2_col0 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row2_col1 {
#             background-color:  #f5f5f5;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row2_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row2_col3 {
#             background-color:  #f4f4f4;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row2_col4 {
#             background-color:  #f8f8f8;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row2_col5 {
#             background-color:  #efefef;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row2_col6 {
#             background-color:  #f5f5f5;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row2_col7 {
#             background-color:  #f4f4f4;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row2_col8 {
#             background-color:  #eeeeee;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row3_col0 {
#             background-color:  #f0f0f0;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row3_col1 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row3_col2 {
#             background-color:  #fefefe;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row3_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row3_col4 {
#             background-color:  #eeeeee;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row3_col5 {
#             background-color:  #efefef;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row3_col6 {
#             background-color:  #f4f4f4;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row3_col7 {
#             background-color:  #f8f8f8;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row3_col8 {
#             background-color:  #ebebeb;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row4_col0 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row4_col1 {
#             background-color:  #ededed;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row4_col2 {
#             background-color:  #f8f8f8;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row4_col3 {
#             background-color:  #e5e5e5;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row4_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row4_col5 {
#             background-color:  #e4e4e4;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row4_col6 {
#             background-color:  #f3f3f3;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row4_col7 {
#             background-color:  #f0f0f0;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row4_col8 {
#             background-color:  #e6e6e6;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row5_col0 {
#             background-color:  #fefefe;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row5_col1 {
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row5_col2 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row5_col3 {
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row5_col4 {
#             background-color:  #f4f4f4;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row5_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row5_col6 {
#             background-color:  #f7f7f7;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row5_col7 {
#             background-color:  #ededed;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row5_col8 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row6_col0 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row6_col1 {
#             background-color:  #f7f7f7;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row6_col2 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row6_col3 {
#             background-color:  #f5f5f5;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row6_col4 {
#             background-color:  #fefefe;
#             color:  #000000;
#         }    #T_aef7c084_7513_11e9_b7ce_51af00dd90a3row6_col5 {
#             background-color:  #f1f1f1;
#             color:  #000000;

# %%
data['X']=0
def fun(srs):
    '''
    if srs.X3>0:
        srs.X3=1 
    if srs.X3<0:
        srs.X3=-1
    if srs.X4>0:
        srs.X4=1 
    if srs.X4<0:
        srs.X4=-1
    if srs.X6>0:
        srs.X6=1 
    if srs.X6<0:
        srs.X6=-1
    if srs.X7>0:
        srs.X7=1 
    if srs.X7<0:
        srs.X7=-1
    if srs.sec_id>0.5:
        srs.sec_id=1 
    else:
        srs.sec_id=0
    '''
    srs.X=srs.X3+srs.X4+srs.X6+srs.X7
    return srs

data.apply(fun,axis=1)

print('*')
# Out:
# *

# %%
data.head()
# Out:
#    Date    sec_id   fut_ret       vol        X1        X3   X4   X6        X7
# 0   0.0  0.000000  0.037521  0.269877  1.876823  0.000000  0.0  0.0  0.000000
# 1   0.0  0.000502  0.005565  0.879423 -0.670540  0.000000  0.0  0.0  0.000000
# 2   0.0  0.001005 -0.008732  0.331473  0.940755  0.923608  0.0  0.0 -0.379818
# 3   0.0  0.001507  0.000695 -0.598987 -0.114191  0.000000  0.0  0.0  0.000000
# 4   0.0  0.002009 -0.002755 -0.057603 -0.101973  0.000000  0.0  0.0  0.000000

# %%
X_all=np.array(data[['sec_id','vol','X1','X3','X4','X6','X7']])
#X_all=np.array(data[['sec_id','X1','X3','X4','X6','X7']])
#X_all=np.array(data[['sec_id','vol','X1','X']])
y_all=np.array(data['fut_ret'])

# test:cv:train=2:2:6
X_all_train, X_all_test, y_all_train, y_all_test = train_test_split(X_all, y_all, test_size=0.2)
X_all_train, X_all_cv, y_all_train, y_all_cv = train_test_split(X_all_train, y_all_train, test_size=0.25)

# Winsorize data
#y_all_train=np.clip(y_all_train,a_min=-0.051681,a_max=0.051951)

train_all=(X_all_train,y_all_train)
cv_all=(X_all_cv,y_all_cv)

# %%
def init_weights(m):
    if type(m) == torch.nn.Linear:
        torch.nn.init.torch.nn.init.kaiming_normal_(m.weight)
        m.bias.data.fill_(0.01)

# %%
def NN( data_set, test_set, nodes=[16], epoch=1000, learning_rate=1e-3, is_drop=False, l2_reg=0, is_leaky=False,
        is_batch=False):
    x = torch.tensor(data_set[0], dtype=torch.float32)
    y = torch.tensor(data_set[1][:, np.newaxis], dtype=torch.float32)
    
    # model initialize
    out_size = 1
    F = x.shape[1]
    layer_num = len(nodes)

    # add layers
    model = torch.nn.Sequential()
    model.add_module("linear 0", torch.nn.Linear(F, nodes[0]))
    if is_batch:
        model.add_module("batch 0",torch.nn.BatchNorm1d(nodes[0]))   
    if is_drop:
        model.add_module("drop 0", torch.nn.Dropout(0.5))
    model.add_module("relu 0", torch.nn.ReLU() if not is_leaky else torch.nn.PReLU())
    

    for i in range(layer_num-1):
        model.add_module("linear "+str(i+1),torch.nn.Linear(nodes[i], nodes[i+1]))
        if is_batch:
            model.add_module("batch "+str(i+1),torch.nn.BatchNorm1d(nodes[i+1]))
        if is_drop:
            model.add_module("drop "+str(i+1), torch.nn.Dropout(0.5))
        model.add_module("relu "+str(i+1), torch.nn.ReLU() if not is_leaky else torch.nn.PReLU())
        
    
    # HE initial
    model.apply(init_weights)
    
    #output layer
    model.add_module("linear "+str(layer_num),
                     torch.nn.Linear(nodes[-1], out_size))

    # loss
    #loss_fn = torch.nn.MSELoss()    
    loss_fn=torch.nn.L1Loss()
    
    # optimizer
    optimizer = torch.optim.Adam(
        model.parameters(), lr=learning_rate, weight_decay=l2_reg)

    # training
    loss_history = []
    loss_old=float('inf')
    loss_new=0
    count=0

    for t in range(epoch):
        y_pred = model(x)

        loss_new = loss_fn(y_pred, y)
        
        if abs(loss_old-loss_new)<1e-9:
            count=count+1
        else:
            count=0
            
        if count>30:
            print("converge epoch: ",t)
            break
            
        loss_old = loss_new
        
        #if loss<0.000296:
        #    print("converge epoch: ",t)
        #    break

        if t % 100 == 99:
            print("epoch ", t+1, ", loss is ", loss_new.item())
        #loss_history.append(loss.item())

        optimizer.zero_grad()

        loss_new.backward()

        optimizer.step()

    # plot loss evolution
    #plt.figure(figsize=(14, 7))
    #plt.plot(range(len(loss_history)), loss_history)
    #plt.xlabel("epoch")
    #plt.ylabel("loss")
    #plt.show()

    # testing
    x_test = torch.tensor(test_set[0], dtype=torch.float32)
    y_test = torch.tensor(test_set[1][:, np.newaxis], dtype=torch.float32)
    
    y_in_pred = model(x)
    y_out_pred = model(x_test)
    
    err_in = loss_fn(y_in_pred, y).item()
    err_out = loss_fn(y_out_pred, y_test).item()
    
       
    y=data_set[1]
    y_test=test_set[1]
    y_in_pred=torch.Tensor.numpy(y_in_pred.data)
    y_in_pred.reshape(y_in_pred.shape[0])
    y_out_pred=torch.Tensor.numpy(y_out_pred.data)
    y_out_pred.reshape(y_out_pred.shape[0])
    
    r2_in = r2_score(y, y_in_pred)
    r2_out = r2_score(y_test, y_out_pred)

    #print("\nin-sample error: ", err_in)
    #print("out-of-sample error: ", err_out)
    #print("in-sample r2: ", r2_in)
    #print("out-of-sample r2: ", r2_out)

    return (model,r2_out,err_in)

# %%
# for test
def test_r2(model,X = X_all_test,y = y_all_test):   
    y_pred=model(torch.tensor(Ｘ, dtype=torch.float32))
    y_pred=torch.Tensor.numpy(y_pred.data)
    y_pred.reshape(y_pred.shape[0])
    plt.figure(figsize=(16,7))
    plt.hist(y_pred,range=(-0.002,0.002),bins=30)
    r2 = r2_score(y, y_pred)
    return r2


def MDA(model,X = X_all_test,y = y_all_test):
    feature_num=X.shape[1]
    r2_origin = test_r2(model,X,y)
    print("origin: ",r2_origin)
    for i in range(feature_num):
        r2_new_lst=[]
        for j in range(10):
            X_new=X.copy()
            np.random.shuffle(X_new[:,i])
            r2_new=test_r2(model,X_new,y)
            r2_new_lst.append(r2_new)
        is_valid=" *"
        if np.mean(r2_new_lst)>r2_origin:
            is_valid=" "
        if abs(np.mean(r2_new_lst)-r2_origin)/abs(r2_origin)<0.01:
            is_valid=" "
        print("suffle feature ",i,": ",np.mean(r2_new_lst),is_valid)

# %%
#MDA(grid_history[-1][1])

# %%
#for i in range(1,len(grid_history)+1):
i=1 
print(grid_history[-i][2:])
print(grid_history[-i][0])
print(test_r2(grid_history[-i][1]),", in sample: ",test_r2(grid_history[-i][1],X_all_train,y_all_train),'\n')
# Out:
# [0.009766577742993832, [128, 16, 16, 16, 16], 10000, 0.01, True, 0.01, True, False]
# -3.273725602381816e-05
# -0.00015823044288620913 , in sample:  -7.560558910357784e-05

# %%
for i in range(1,len(grid_history2)+1):
    print(grid_history2[-i][2:])
    print(grid_history2[-i][0])
    print(test_r2(grid_history2[-i][1]),", in sample: ",test_r2(grid_history2[-i][1],X_all_train,y_all_train),'\n')

for i in range(1,len(grid_history1)+1):
    print(grid_history1[-i][2:])
    print(grid_history1[-i][0])
    print(test_r2(grid_history1[-i][1]),", in sample: ",test_r2(grid_history1[-i][1],X_all_train,y_all_train),'\n')
# Out:
# [0.00030693586450070143, [64, 64], 10000, 0.001, True, 0.01, True, True]
# -3.777797376791625e-05
# -3.45969867421303e-06 , in sample:  1.3267498535696198e-05
#
# [0.0003069373487960547, [64, 64], 10000, 0.001, True, 0.1, False]
# -4.880653519845346e-05
# -9.10207280102604e-06 , in sample:  1.4115906080247598e-05
#
# [0.0003069371450692415, [64, 64], 10000, 0.001, True, 0.1, True]
# -4.105563740153251e-05
# -2.7479496396143333e-06 , in sample:  1.010154744240932e-05
#
# [0.00030693921144120395, [64, 64], 10000, 0.001, True, 0.01, False]
# -3.91739795324586e-05
# -3.850801181481955e-06 , in sample:  4.76217728295758e-06
#
# [0.0003069363592658192, [64, 64], 10000, 0.001, True, 0.01, True]
# -3.09392828132804e-05
# 2.188198898633864e-06 , in sample:  1.2539210090700692e-05
#
# [0.00030694264569319785, [64, 64], 10000, 0.001, True, 0.001, False]
# -6.496190237958999e-05
# -2.3159146008477904e-05 , in sample:  -4.726967861801157e-06
#
# [0.0003069372905883938, [64, 64], 10000, 0.001, True, 0.001, True]
# -3.73809510296752e-05
# -5.332258717238858e-06 , in sample:  1.2086423034962657e-05
#
# [0.009767658077180386, [128], 10000, 0.001, False, 0.01, True]
# -0.00013317449458494224
# -0.00018029946927167195 , in sample:  0.00018076985441539684
#
# [0.00976388156414032, [128], 10000, 0.001, True, 0.01, True]
# -0.0001220048403127727
# -0.00011727584293086402 , in sample:  0.00011840606782731466
#
# [0.000151650354382582, [16], 10000, 0.001, True, 0.01, True]
# -2.1809228486713295e-05
# 2.681923744884962e-05 , in sample:  2.5080291474521843e-05
#
# [0.00015164098294917494, [128], 10000, 0.001, True, 0.01, True]
# 3.7075007633391444e-05
# 2.706134263241733e-05 , in sample:  8.86744981269949e-05
#
# [0.0001917474583024159, [128], 10000, 0.001, True, 0.01, True, 'no winzor']
# 7.517185829486461e-05
# 3.316822007459752e-05 , in sample:  0.00010053058193826292
#
# [0.00019175559282302856, [128], 10000, 0.001, True, 0.082, True]
# 4.4420803010036813e-05
# 2.281157709294046e-05 , in sample:  5.0019213758245584e-05
#
# [0.0001917533081723377, [128], 10000, 0.001, True, 0.064, True]
# 4.892152504898384e-05
# 9.731178680416619e-06 , in sample:  7.389248792222247e-05
#
# [0.00019174649787601084, [128], 10000, 0.001, True, 0.046000000000000006, True]
# 7.16017126132229e-05
# 5.4613939621139806e-05 , in sample:  9.888394701274006e-05
#
# [0.00019175378838554025, [128], 10000, 0.001, True, 0.028000000000000004, True]
# 4.659007174945273e-05
# 2.6248052666932864e-05 , in sample:  6.287987321407229e-05
#
# [0.00019174600311089307, [128], 10000, 0.001, True, 0.01, True]
# 9.784048693473046e-05
# 3.9759042826936764e-05 , in sample:  0.00010570289874489713
#
# [0.00019174419867340475, [128], 10000, 0.001, True, 0.01, True, 'drop']
# 9.06310965320678e-05
# 4.915537275607118e-05 , in sample:  0.00011736983765664455
#
# [0.00019182643154636025, [128], 10000, 0.001, True, 0.01, True]
# -3.476185167183843e-05
# 1.1245467970599776e-05 , in sample:  4.6914138882248047e-05
#
# [0.0001927547564264387, [128], 10000, 0.0005, True, 0.01, True]
# 3.7373040020716175e-05
# 3.189664037572815e-05 , in sample:  7.204465939592009e-05
#
# [0.0001927526027429849, [128], 10000, 0.0005, True, 0.01, True]
# 3.753512265236569e-05
# 3.862961727785219e-05 , in sample:  7.465169530207483e-05
#
# [0.0002960353740490973, [256], 10000, 0.0005, True, 0.01, True]
# 6.17988132133318e-05
# 4.829540508077823e-05 , in sample:  7.856464186417611e-05
#
# [0.0002960370038636029, [128], 10000, 0.0005, True, 0.01, True]
# 5.392339071641494e-05
# 3.863717390650834e-05 , in sample:  6.69343235560893e-05
#
# [0.00029604381415992975, [128], 10000, 0.0005, True, 0.01, False]
# 2.9388866181867535e-05
# 2.5488791703165425e-05 , in sample:  4.935653797244477e-05
#
# [0.0002960505662485957, [64], 10000, 0.0005, True, 0.01, False]
# 2.2890820587040395e-05
# 1.8661915637152582e-05 , in sample:  2.447068311295375e-05
#
# [0.0002960552810691297, [32], 10000, 0.0005, True, 0.01, False]
# 5.4833316693869705e-06
# 9.135597534570827e-06 , in sample:  1.1023809978416566e-05
#
# [0.0002960546116810292, [16], 10000, 0.0005, True, 0.01, False]
# 5.54229176430443e-06
# 4.774958786701866e-06 , in sample:  8.73242123600182e-06

# %%
#for i in np.linspace(1e-3,1e-2,4):
model,r2,mse=NN(train_all,cv_all,[128], 10000, 1e-3, False, 1e-2, True,False)
grid_history.append([r2,model,mse,[128], 10000, 1e-3, False, 1e-2, True])
print(t,": ",r2,"  ",mse,"  ",[128], False, 1e-2, True)
# Out:
# epoch  1000 , loss is  0.009981795214116573
# epoch  2000 , loss is  0.00981492456048727
# epoch  3000 , loss is  0.009771928191184998
# epoch  4000 , loss is  0.009785587899386883
# epoch  5000 , loss is  0.009777273051440716
# epoch  6000 , loss is  0.00976316723972559
# epoch  7000 , loss is  0.009769751690328121
# epoch  8000 , loss is  0.009774324484169483
# epoch  9000 , loss is  0.009762054309248924
# epoch  10000 , loss is  0.009772260673344135
# 7 :  -0.00013317449458494224    0.009767658077180386    [128] False 0.01 True

# %% [markdown]
# ### DAY 1 Experiment

# %%
grid_history=[]

# %%
nodes_list=[
    [128,16,16,16,16]
]          

t=1 
for nodes in nodes_list:
    for epoch in [10000]:
        for lr in [1e-2]:
            for isdrop in [True]:
                for l2reg in [1e-2]:
                    for isleaky in [True]:
                        for isbatch in [False]:
                            model,r2,mse=NN(train_all,cv_all,nodes, epoch, lr, isdrop, l2reg, isleaky, isbatch)
                            grid_history.append([r2,model,mse,nodes, epoch, lr, isdrop, l2reg, isleaky, isbatch])
                            print(t,": ",r2,"  ",mse,"  ",nodes, isdrop, l2reg, isleaky, isbatch)
                            t=t+1
# Out:
# epoch  100 , loss is  0.009800838306546211
# epoch  200 , loss is  0.009743771515786648
# epoch  300 , loss is  0.009791131131350994
# epoch  400 , loss is  0.009794083423912525
# epoch  500 , loss is  0.009795330464839935
# epoch  600 , loss is  0.009794903919100761
# epoch  700 , loss is  0.009797940030694008
# epoch  800 , loss is  0.009800132364034653
# epoch  900 , loss is  0.009797788225114346
# epoch  1000 , loss is  0.009797954000532627
# epoch  1100 , loss is  0.00979797076433897
# epoch  1200 , loss is  0.009798044338822365
# epoch  1300 , loss is  0.009802669286727905
# epoch  1400 , loss is  0.009802654385566711
# epoch  1500 , loss is  0.009802711196243763
# epoch  1600 , loss is  0.009802712127566338
# epoch  1700 , loss is  0.009802759625017643
# epoch  1800 , loss is  0.00980278942734003
# epoch  1900 , loss is  0.00980279128998518
# epoch  2000 , loss is  0.009802772663533688
# epoch  2100 , loss is  0.009802852757275105
# epoch  2200 , loss is  0.00980284996330738
# epoch  2300 , loss is  0.00980285182595253
# epoch  2400 , loss is  0.009802861139178276
# epoch  2500 , loss is  0.009802861139178276
# epoch  2600 , loss is  0.00980286579579115
# epoch  2700 , loss is  0.009802860207855701
# epoch  2800 , loss is  0.009802868589758873
# epoch  2900 , loss is  0.009802875109016895
# epoch  3000 , loss is  0.009802869521081448
# epoch  3100 , loss is  0.009802883490920067
# epoch  3200 , loss is  0.009802884422242641
# epoch  3300 , loss is  0.009802871383726597
# epoch  3400 , loss is  0.009802883490920067
# epoch  3500 , loss is  0.009802867658436298
# epoch  3600 , loss is  0.00980288628488779
# epoch  3700 , loss is  0.009802867658436298
# epoch  3800 , loss is  0.00980288814753294
# epoch  3900 , loss is  0.009802889078855515
# epoch  4000 , loss is  0.009802884422242641
# epoch  4100 , loss is  0.009797841310501099
# epoch  4200 , loss is  0.009808728471398354
# epoch  4300 , loss is  0.00980862881988287
# epoch  4400 , loss is  0.009808646515011787
# epoch  4500 , loss is  0.009808694943785667
# epoch  4600 , loss is  0.009808693081140518
# epoch  4700 , loss is  0.009808698669075966
# epoch  4800 , loss is  0.009808718226850033
# epoch  4900 , loss is  0.009808719158172607
# epoch  5000 , loss is  0.009808719158172607
# epoch  5100 , loss is  0.009808746166527271
# epoch  5200 , loss is  0.009808756411075592
# epoch  5300 , loss is  0.009808747097849846
# epoch  5400 , loss is  0.009808756411075592
# epoch  5500 , loss is  0.00980876013636589
# epoch  5600 , loss is  0.009808741509914398
# epoch  5700 , loss is  0.009808753617107868
# epoch  5800 , loss is  0.009808745235204697
# epoch  5900 , loss is  0.009808770380914211
# epoch  6000 , loss is  0.009808768518269062
# epoch  6100 , loss is  0.00980874802917242
# epoch  6200 , loss is  0.009808767586946487
# epoch  6300 , loss is  0.009808759205043316
# epoch  6400 , loss is  0.009808741509914398
# epoch  6500 , loss is  0.009808768518269062
# epoch  6600 , loss is  0.00980877410620451
# epoch  6700 , loss is  0.009808750823140144
# epoch  6800 , loss is  0.009808776900172234
# epoch  6900 , loss is  0.009808783419430256
# epoch  7000 , loss is  0.009808770380914211
# epoch  7100 , loss is  0.009808768518269062
# epoch  7200 , loss is  0.009808768518269062
# epoch  7300 , loss is  0.009808768518269062
# epoch  7400 , loss is  0.009824453853070736
# epoch  7500 , loss is  0.009804720990359783
# epoch  7600 , loss is  0.009802879765629768
# epoch  7700 , loss is  0.009802878834307194
# epoch  7800 , loss is  0.009802883490920067
# epoch  7900 , loss is  0.009802895598113537
# epoch  8000 , loss is  0.009802667424082756
# epoch  8100 , loss is  0.009861445985734463
# epoch  8200 , loss is  0.00980279128998518
# epoch  8300 , loss is  0.009802871383726597
# epoch  8400 , loss is  0.009802858345210552
# epoch  8500 , loss is  0.009802880696952343
# epoch  8600 , loss is  0.009802878834307194
# epoch  8700 , loss is  0.009802878834307194
# epoch  8800 , loss is  0.009802869521081448
# epoch  8900 , loss is  0.00980288814753294
# epoch  9000 , loss is  0.009802887216210365
# epoch  9100 , loss is  0.009802864864468575
# epoch  9200 , loss is  0.009824912063777447
# epoch  9300 , loss is  0.00977939274162054
# epoch  9400 , loss is  0.00977924931794405
# epoch  9500 , loss is  0.009779252111911774
# epoch  9600 , loss is  0.009779279120266438
# epoch  9700 , loss is  0.009779246523976326
# epoch  9800 , loss is  0.00980274099856615
# epoch  9900 , loss is  0.009835243225097656
# epoch  10000 , loss is  0.00977922324091196
# 1 :  -3.273725602381816e-05    0.009766577742993832    [128, 16, 16, 16, 16] True 0.01 True False

# %%
# write history
##with open('grid_history_1layer.data', 'wb') as filehandle:  
    pickle.dump(grid_history, filehandle)

# %%
# load history
with open('grid_history_2layer.data', 'rb') as filehandle:  
    grid_history2 = pickle.load(filehandle)
    
with open('grid_history_1layer.data', 'rb') as filehandle:  
    grid_history1 = pickle.load(filehandle)

# %%
# save whole model
torch.save(model, PATH)

# %%
# load whole model
model = torch.load(PATH)
model.eval()

# %%
ind=['r2','mse','nodes', 'isdrop', 'l2reg', 'isleaky']
s=[0,2,3,6,7,8]
record_df={}
for i in range(len(s)):
    tmp=[]
    for lst in grid_history:
        tmp.append(lst[i])
    record_df[ind[i]]=tmp

record_df=pd.DataFrame(record_df)

# %%
possible_node=[16,32]
nodes_list=[]
for k in possible_node:
    nodes_list.append([k])
for k1 in possible_node:
    for k2 in possible_node:
        nodes_list.append([k1,k2])
for k1 in possible_node:
    for k2 in possible_node:
        for k3 in possible_node:
            nodes_list.append([k1,k2,k3])

# %%
torch.__version__
# Out:
# '1.1.0'
